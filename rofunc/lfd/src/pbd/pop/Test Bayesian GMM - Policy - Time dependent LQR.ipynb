# %%
import numpy as np
import pbdlib as pbd
import matplotlib.pyplot as plt

from IPython.core import display

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Loading demos

# %%
demo_name = 'policy_001'

# %%
data = np.load('./data/tests/%s.npy' % demo_name, allow_pickle = True, encoding='latin1')[()]

# %%
x_in = np.concatenate(data['x'], axis=0)
x_out = np.concatenate(data['dx'], axis=0)
x_joint = np.concatenate([x_in, x_out], axis=1)

data['xdx'] = [np.concatenate([x, dx], axis=1) for x, dx in zip(data['x'], data['dx'])]

# %%
for d in data['x']:
    plt.plot(d[:, 0], d[:, 1])
    
plt.axes().set_aspect(True)
plt.xlabel(r'$x_{in}$')
plt.ylabel(r'$x_{out}$')
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
# Text(0, 0.5, '$x_{out}$')

# %%
n_in = x_in.shape[1]
n_out = x_out.shape[1]
n_joint = x_joint.shape[1]
n_data = x_joint.shape[0]

# %% [markdown]
# ### Covariance prior

# %%
cov_tril = 14. * np.eye(4)
cov = cov_tril.T.dot(cov_tril)

# %% [markdown]
# ###  Create model
# Parameters are the same as in [sklearn](https://scikit-learn.org/stable/modules/generated/sklearn.mixture.BayesianGaussianMixture.html).

# %%
joint_model = pbd.VBayesianGMM({
        'n_components':23, 'n_init':1, 'reg_covar': 0.6 ** 2,
        'covariance_prior': cov, 'mean_precision_prior':20. ** -2,
        'weight_concentration_prior_type':'dirichlet_process', 'weight_concentration_prior': 1e3,
        'degrees_of_freedom_prior': n_joint - 1. + 0.3 })

# %%
joint_model.posterior(data=x_joint)

# %%
fig, ax = plt.subplots(nrows=n_joint-1, ncols=n_joint-1, figsize=(10, 10))

for i in range(n_joint):
    for j in range(n_joint):
        if not i == j and j>i:
            for d in data['xdx']:
                ax[i][j-1].plot(d[:, i], d[:, j])
                
            joint_model.get_used_states().plot(dim=[i, j], ax=ax[i][j-1], alpha=0.2)
            ax[i][j-1].autoscale(False)
            joint_model.plot(dim=[i, j], ax=ax[i][j-1], alpha=0.05)

# %%
def f(x, use_gmr=False):
    return joint_model.condition(x, slice(0, n_in), slice(n_in, n_joint), moment_matching=True)[0]

# %%
def uncertainty(x):
    return -np.log(joint_model.get_pred_post_uncertainty(x, slice(0, n_in), slice(n_in, n_joint)))

# %% [markdown]
# ### Bayesian DP-GMM policy

# %%
plt.figure(figsize=(8, 8))
pbd.plot_dynamic_system(f, xlim=[-100, 100], ylim=[-100, 100], equal=True, scale=0.05)
pbd.plot_function_map(uncertainty, xlim=[-100, 100], ylim=[-100, 100], nb_sub=80, opp=False)
# joint_model.plot(dim=[0, 1], alpha=0.2)
for d in data['x']:
    plt.plot(d[:, 0], d[:, 1], 'k', lw=2)
# Out:
# c:\users\hakan\documents\codes\gitlab_idiap\pbdlib-python\pbdlib\plot.py:633: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal')

# %% [markdown]
# ### Create stable controller

# %%
dt = 0.05

# %%
A = np.eye(2)
B = dt * np.eye(2) 
T = max([d.shape[0] for d in data['x']]) + 50

# %%
lqr = pbd.LQR(A, B, horizon=T)

# %%
cost_xi = pbd.GMM(nb_states=2, nb_dim=2)

diag = lambda x: np.eye(x.shape[-1]) * x

cost_xi.mu = np.array([
    # data distribution
    np.mean(x_joint[:, :2], axis=0), 
    # end state distribution
    np.mean([d[-1] for d in data['x']], axis=0)
])

cost_xi.sigma = [
    8 * diag(np.cov(x_joint[:, :2], rowvar=False)), # data distribution
    4 * diag(np.cov([d[-1] for d in data['x']],rowvar=False)) # end state distribution 
]

cost_u = pbd.MVN(nb_dim=2)

cost_u.mu = np.zeros(2)
cost_u.sigma = 8. * diag(np.cov(x_joint[:, 2:], rowvar=False))

# %%
lqr.gmm_xi = cost_xi, [0 for i in range(T - 50)] + [1 for i in range(50)]
lqr.gmm_u = cost_u

# %%
lqr.ricatti()

# %%
def stable_policy(x, t=0):
    return np.einsum('ij,ai->aj', lqr.K[t], lqr.ds[t]-x), lqr.Qc[t] * np.ones_like(x)[:, :, None]

# %% [markdown]
# ## Product of policies

# %%
def product_policy(x, t=0):
    mu_1, sigma_1 = joint_model.condition(x, slice(0, n_in), slice(n_in, n_joint),moment_matching=True)
    mu_2, sigma_2 = stable_policy(x, t)
    
    lmbda_1, lmbda_2 = np.linalg.inv(sigma_1), np.linalg.inv(sigma_2) 
    lmbda_p = lmbda_1 + lmbda_2
    
    mu_p = np.einsum('aij,aj->ai',np.linalg.inv(lmbda_p),(np.einsum('aij,aj->ai', lmbda_1, mu_1) +
     np.einsum('aij,aj->ai', lmbda_2, mu_2)))
    return mu_p

# %%
xis = [np.copy(data['x'][2][0])]


for i in range(0, T-6):
    u = product_policy(xis[-1][None], i)[0]
    xis += [A.dot(xis[-1]) + B.dot(u)]
    
xis = np.array(xis)

# %%
fig, ax= plt.subplots(ncols=2, figsize=(16, 8))

pbd.plot_dynamic_system(
    lambda x: product_policy(x, t=0),
    xlim=[-100, 100], ylim=[-100, 100], equal=True, scale=0.02, ax=ax[0],
    color='steelblue'
)

pbd.plot_dynamic_system(
    lambda x: product_policy(x, t=-50),
    xlim=[-100, 100], ylim=[-100, 100], equal=True, scale=0.02, ax=ax[1],
    color='steelblue'
)


for i in range(2):
    pbd.plot_function_map(
        uncertainty, xlim=[-100, 100], ylim=[-100, 100], nb_sub=40, opp=False, ax=ax[i])

    for d in data['x']:
        ax[i].plot(d[:, 0], d[:, 1], 'k', lw=2)

        ax[i].plot(xis[:, 0], xis[:, 1], lw=4, color='orangered')

# %%
import imageio
import os

# %%
images = []
name = demo_name + '_dp_gmm_lqr'
# for t in range(0, 6, 6):
for t in range(0, T-6, 3):
    plt.figure(figsize=(8, 8))
    
    pbd.plot_dynamic_system(
        lambda x: product_policy(x, t=t),
        xlim=[-100, 100], ylim=[-100, 100], equal=True, scale=0.03,
        color='steelblue'
    )
    
    pbd.plot_function_map(
        uncertainty, xlim=[-100, 100], ylim=[-100, 100], nb_sub=40, opp=False)
    
    for d in data['x']:
        plt.plot(d[:, 0], d[:, 1], 'k--', lw=2, alpha=0.6)
        
    plt.plot(xis[:t, 0], xis[:t, 1], color='orangered', lw=3)
    plt.plot(xis[t, 0], xis[t, 1], 'ws', mec='orangered', ms=10, mew=2)
    
    plt.savefig('img_%d.png' % t)
    
    images.append(imageio.imread('img_%d.png' % t))
    os.remove('img_%d.png' % t)
    plt.close()
    
imageio.mimsave('%s.mp4' % name, images)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-7ef96bf440e8> in <module>
#       8         lambda x: product_policy(x, t=t),
#       9         xlim=[-100, 100], ylim=[-100, 100], equal=True, scale=0.03,
# ---> 10         color='steelblue'
#      11     )
#      12
#
# c:\users\hakan\documents\codes\gitlab_idiap\pbdlib-python\pbdlib\plot.py in plot_dynamic_system(f, nb_sub, ax, xlim, ylim, scale, name, equal, **kwargs)
#     626
#     627     else:
# --> 628         strm = plt.streamplot(X, Y, U, V, linewidth=scale * speed, **kwargs)
#     629         plt.xlim(xlim)
#     630         plt.ylim(ylim)
#
# D:\Anaconda\lib\site-packages\matplotlib\pyplot.py in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, data)
#    2929         maxlength=maxlength,
#    2930         integration_direction=integration_direction, **({"data": data}
# -> 2931         if data is not None else {}))
#    2932     sci(__ret.lines)
#    2933     return __ret
#
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Anaconda\lib\site-packages\matplotlib\streamplot.py in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction)
#     225     axes.autoscale_view()
#     226
# --> 227     ac = matplotlib.collections.PatchCollection(arrows)
#     228     stream_container = StreamplotSet(lc, ac)
#     229     return stream_container
#
# D:\Anaconda\lib\site-packages\matplotlib\collections.py in __init__(self, patches, match_original, **kwargs)
#    1805         Collection.__init__(self, **kwargs)
#    1806
# -> 1807         self.set_paths(patches)
#    1808
#    1809     def set_paths(self, patches):
#
# D:\Anaconda\lib\site-packages\matplotlib\collections.py in set_paths(self, patches)
#    1809     def set_paths(self, patches):
#    1810         paths = [p.get_transform().transform_path(p.get_path())
# -> 1811                  for p in patches]
#    1812         self._paths = paths
#    1813
#
# D:\Anaconda\lib\site-packages\matplotlib\collections.py in <listcomp>(.0)
#    1809     def set_paths(self, patches):
#    1810         paths = [p.get_transform().transform_path(p.get_path())
# -> 1811                  for p in patches]
#    1812         self._paths = paths
#    1813
#
# D:\Anaconda\lib\site-packages\matplotlib\patches.py in get_path(self)
#    4260         in display coordinates.
#    4261         """
# -> 4262         _path, fillable = self.get_path_in_displaycoord()
#    4263
#    4264         if np.iterable(fillable):
#
# D:\Anaconda\lib\site-packages\matplotlib\patches.py in get_path_in_displaycoord(self)
#    4283                                                patchB=self.patchB,
#    4284                                                shrinkA=self.shrinkA * dpi_cor,
# -> 4285                                                shrinkB=self.shrinkB * dpi_cor
#    4286                                                )
#    4287         else:
#
# D:\Anaconda\lib\site-packages\matplotlib\patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2825
#    2826             clipped_path = self._clip(path, patchA, patchB)
# -> 2827             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2828
#    2829             return shrunk_path
#
# D:\Anaconda\lib\site-packages\matplotlib\patches.py in _shrink(self, path, shrinkA, shrinkB)
#    2810                 insideB = inside_circle(*path.vertices[-1], shrinkB)
#    2811                 try:
# -> 2812                     path, right = split_path_inout(path, insideB)
#    2813                 except ValueError:
#    2814                     pass
#
# D:\Anaconda\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# D:\Anaconda\lib\site-packages\matplotlib\bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     253     bp = bezier_path.reshape((-1, 2))
#     254     left, right = split_bezier_intersecting_with_closedpath(
# --> 255         bp, inside, tolerance)
#     256     if len(left) == 2:
#     257         codes_left = [Path.LINETO]
#
# D:\Anaconda\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# D:\Anaconda\lib\site-packages\matplotlib\bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     192
#     193     t0, t1 = find_bezier_t_intersecting_with_closedpath(
# --> 194         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     195
#     196     _left, _right = split_de_casteljau(bezier, (t0 + t1) / 2.)
#
# D:\Anaconda\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# D:\Anaconda\lib\site-packages\matplotlib\bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     132         # calculate the middle point
#     133         middle_t = 0.5 * (t0 + t1)
# --> 134         middle = bezier_point_at_t(middle_t)
#     135         middle_inside = inside_closedpath(middle)
#     136
#
# D:\Anaconda\lib\site-packages\matplotlib\bezier.py in point_at_t(self, t)
#     173         "evaluate a point at t"
#     174         tt = ((1 - t) ** self._orders)[::-1] * t ** self._orders
# --> 175         _x = np.dot(tt, self._px)
#     176         _y = np.dot(tt, self._py)
#     177         return _x, _y
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
